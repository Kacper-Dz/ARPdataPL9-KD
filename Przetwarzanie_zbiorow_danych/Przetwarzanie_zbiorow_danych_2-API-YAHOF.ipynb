# %%
import yahoo_fin.stock_info as yh

# %%
response = yh.get_day_gainers()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = yh.get_day_gainers()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\yahoo_fin\stock_info.py:620, in get_day_gainers(count)
#     618 def get_day_gainers(count: int = 100):
# --> 620     return _raw_get_daily_info(f"https://finance.yahoo.com/gainers?offset=0&count={count}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\yahoo_fin\stock_info.py:606, in _raw_get_daily_info(site)
#     603 for field in fields_to_change:
#     605     if type(df[field][0]) == str:
# --> 606         df[field] = df[field].map(_convert_to_numeric)
#     608 session.close()
#     610 return df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
# ...

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
msft_data = yh.get_data('msft')
msft_data
# Out:
#                   open        high         low       close    adjclose  \
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...                ...         ...         ...         ...         ...
# 2023-03-29  278.959991  281.140015  278.410004  280.510010  280.510010
# 2023-03-30  284.230011  284.459991  281.480011  284.049988  284.049988
# 2023-03-31  283.730011  289.269989  283.000000  288.299988  288.299988
# 2023-04-03  286.519989  288.269989  283.950012  287.230011  287.230011
# 2023-04-04  287.230011  290.449890  286.329987  287.825012  287.825012
#
#                 volume ticker
# 1986-03-13  1031788800   MSFT
# 1986-03-14   308160000   MSFT
# ...
