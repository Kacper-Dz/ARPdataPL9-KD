# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

def apply_filter(source, kernel):
 new_image = cv2.filter2D(source, -1, kernel)
 cv2_imshow(new_image)
 return new_image

# %%
def cv2_imshow(img): # Funkcja dla jupytera
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

# %%
# Wczytanie kolorowego obrazu
image_path = 'ML-datasets/images/gory_lc.png'
img = cv2.imread(image_path)
cv2_imshow(img)

# %%
#idendity
idendity_kernel = np.array([[0, 0, 0],
                           [0, 1, 0],
                           [0, 0, 0]])
apply_filter(img, idendity_kernel)
# Out:
# array([[[ 73,  68,  69],
#         [ 72,  62,  62],
#         [ 84,  78,  79],
#         ...,
#         [ 78,  76,  76],
#         [ 39,  32,  29],
#         [ 53,  60,  57]],
#
#        [[ 87,  82,  83],
#         [ 74,  66,  66],
#         [ 77,  70,  67],
#         ...,
#         [ 63,  61,  61],
#         [ 74,  93,  98],
#         [ 96, 116, 121]],
#
#        [[ 80,  69,  71],
#         [ 85,  80,  77],
#         [ 87,  78,  74],
#         ...,
#         [102, 121, 128],
#         [109, 128, 135],
#         [ 92, 104, 108]],
#
#        ...,
#
#        [[ 20,  38,  67],
#         [ 18,  38,  63],
#         [ 17,  40,  66],
#         ...,
#         [ 85,  88,  86],
#         [100,  96,  85],
#         [115, 101,  83]],
#
#        [[ 17,  47,  74],
#         [ 14,  48,  78],
#         [ 13,  50,  76],
#         ...,
#         [ 34,  79,  92],
#         [ 38,  73,  86],
#         [ 50,  80,  85]],
#
#        [[ 16,  50,  80],
#         [  9,  43,  73],
#         [  9,  48,  76],
#         ...,
#         [ 42,  84,  97],
#         [ 42,  85,  94],
#         [ 40,  87,  95]]], dtype=uint8)

# %%
#blur
blur_kernel = np.ones((3, 3), np.float32) / 9
apply_filter(img, blur_kernel)
# Out:
# array([[[ 76,  69,  69],
#         [ 78,  72,  71],
#         [ 79,  72,  71],
#         ...,
#         [ 75,  79,  80],
#         [ 71,  79,  80],
#         [ 69,  81,  83]],
#
#        [[ 78,  71,  70],
#         [ 80,  73,  72],
#         [ 81,  74,  73],
#         ...,
#         [ 81,  88,  90],
#         [ 78,  88,  90],
#         [ 76,  87,  90]],
#
#        [[ 82,  77,  77],
#         [ 85,  79,  80],
#         [ 87,  81,  81],
#         ...,
#         [ 89, 103, 107],
#         [ 86, 103, 107],
#         [ 89, 107, 112]],
#
#        ...,
#
#        [[ 18,  43,  71],
#         [ 18,  44,  72],
#         [ 15,  46,  74],
#         ...,
#         [ 82,  92,  88],
#         [ 90,  92,  86],
#         [ 92,  93,  85]],
#
#        [[ 15,  44,  72],
#         [ 15,  45,  73],
#         [ 13,  46,  75],
#         ...,
#         [ 53,  85,  89],
#         [ 61,  86,  89],
#         [ 63,  86,  88]],
#
#        [[ 14,  47,  76],
#         [ 14,  48,  76],
#         [ 12,  49,  79],
#         ...,
#         [ 37,  81,  90],
#         [ 41,  80,  90],
#         [ 42,  79,  89]]], dtype=uint8)

# %%
#sharpen
sharpen_kernel = np.array([[0, -1, 0],
                          [-1, 5, -1],
                          [0, -1, 0]])

apply_filter(img, sharpen_kernel)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#simply_edge_detection
simply_edge_kernel = np.array([[-1, -1, -1],
                              [-1, 8, -1],
                              [-1, -1, -1]])

apply_filter(gray_img, simply_edge_kernel)
# Out:
# array([[  0,   0,  56, ...,   0,   0,   0],
#        [104,   0,   0, ...,   0,  41, 254],
#        [  0,   0,   0, ..., 166, 233,   0],
#        ...,
#        [  0,   0,   0, ...,   0,  27,  62],
#        [ 28,  30,  25, ...,   0,   0,   0],
#        [ 28,   0,   0, ...,  35,  39,  58]], dtype=uint8)

# %%
#bottom sobel
bottom_sobel_kernel = np.array([[-1, -2, -1],
                               [0, 0, 0],
                               [1, 2, 1]])

bottom_sobel = apply_filter(gray_img, bottom_sobel_kernel)

# %%
#bottom sobel
left_sobel_kernel = np.array([[1, 0, -1],
                             [2, 0, -2],
                             [1, 0, -1]])

left_sobel = apply_filter(gray_img, left_sobel_kernel)

# %%
#sobel
sobel = left_sobel/2 + bottom_sobel/2
cv2_imshow(sobel)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 3
#       1 #sobel
#       2 sobel = left_sobel/2 + bottom_sobel/2
# ----> 3 cv2_imshow(sobel)
#
# Cell In[5], line 2, in cv2_imshow(img)
#       1 def cv2_imshow(img): # Funkcja dla jupytera
# ----> 2     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3     plt.imshow(img)
#       4     plt.show()
#
# error: OpenCV(4.7.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:94: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0x981fb336::Set<3,4,-1>,struct cv::impl::A0x981fb336::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Unsupported depth of input image:
# >     'VDepth::contains(depth)'
# > where
# >     'depth' is 6 (CV_64F)
