# %%
import yahoo_fin.stock_info as yh

# %%
response = yh.get_day_gainers()

# %%
response
# Out:
#    Symbol                                           Name  Price (Intraday)  \
# 0     BUR                        Burford Capital Limited             11.06
# 1   KPELY                     Keppel Corporation Limited              8.45
# 2   SYRVF                                    Sacyr, S.A.              2.72
# 3      AI                                    C3.ai, Inc.             33.57
# 4    PACB        Pacific Biosciences of California, Inc.             11.58
# ..    ...                                            ...               ...
# 95   EXTR                         Extreme Networks, Inc.             19.12
# 96   APPN                             Appian Corporation             44.38
# 97  SHZHY  Shenzhou International Group Holdings Limited             10.34
# 98   DUOL                                 Duolingo, Inc.            142.59
# 99    NEP                    NextEra Energy Partners, LP             60.75
#
#     Change  % Change      Volume  Avg Vol (3 month)    Market Cap  \
# ...

# %%
msft_data = yh.get_data('msft')
msft_data
# Out:
#                   open        high         low       close    adjclose  \
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063906
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...                ...         ...         ...         ...         ...
# 2023-03-27  280.500000  281.459991  275.519989  276.380005  276.380005
# 2023-03-28  275.790009  276.140015  272.049988  275.230011  275.230011
# 2023-03-29  278.959991  281.140015  278.410004  280.510010  280.510010
# 2023-03-30  284.230011  284.459991  281.480011  284.049988  284.049988
# 2023-03-31  283.730011  289.269989  283.000000  288.299988  288.299988
#
#                 volume ticker
# 1986-03-13  1031788800   MSFT
# 1986-03-14   308160000   MSFT
# ...
