# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [1,4,2,3])

# %%
dane = pd.DataFrame({'Czas' : [0,1,2,3,4,5],
                     'Sprzedaz' : [300,500,400,200,1000,120] })

# %%
dane
# Out:
#    Czas  Sprzedaz
# 0     0       300
# 1     1       500
# 2     2       400
# 3     3       200
# 4     4      1000
# 5     5       120

# %%
fig, ax = plt.subplots()
ax.plot(dane)
# Out:
# [<matplotlib.lines.Line2D at 0x26bed13df70>,
#  <matplotlib.lines.Line2D at 0x26bed13dfd0>]

# %%
fig, ax = plt.subplots()
ax.set_title("Pierwszy wykres")
ax.plot(dane)
# Out:
# [<matplotlib.lines.Line2D at 0x26bed1bf130>,
#  <matplotlib.lines.Line2D at 0x26bed1bf190>]

# %%
fig, ax = plt.subplots()
ax.set_title("Pierwszy wykres")
ax.set_xlabel('Czas')
ax.set_ylabel('Sprzedaż')
ax.plot(dane['Sprzedaz'])

# %%
fig, ax = plt.subplots()
ax.set_title("Pierwszy wykres")
ax.set_xlabel('Czas')
ax.set_ylabel('Sprzedaż')
ax.plot(dane['Sprzedaz'])
for i,j in zip(dane['Czas'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.set_title("Pierwszy wykres")
ax.set_xlabel('Czas')
ax.set_ylabel('Sprzedaż')
ax.plot(dane['Sprzedaz'])
for i,j in zip(dane['Czas'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))

# %%
dane['Sprzedaz2'] = dane['Sprzedaz'] + 100
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2
# 0     0       300        400
# 1     1       500        600
# 2     2       400        500
# 3     3       200        300
# 4     4      1000       1100
# 5     5       120        220

# %%
fig, ax = plt.subplots(figsize=(20,10))



ax.set_title("Pierwszy wykres")
ax.set_xlabel('Czas')
ax.set_ylabel('Sprzedaż')




ax.plot(dane['Sprzedaz'])
for i,j in zip(dane['Czas'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
    
ax.plot(dane['Sprzedaz2'])
for i,j in zip(dane['Czas'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
from datetime import datetime
datatime_list = [datetime(2021, 11, 18, 12), datetime(2021, 11, 18, 14), datetime(2021, 11, 18, 16),datetime(2021, 11, 18, 18), datetime(2021, 11, 18, 20), datetime(2021, 11, 18, 22)]
dane['DT'] = datatime_list

# %%
dane['DT']
# Out:
# 0   2021-11-18 12:00:00
# 1   2021-11-18 14:00:00
# 2   2021-11-18 16:00:00
# 3   2021-11-18 18:00:00
# 4   2021-11-18 20:00:00
# 5   2021-11-18 22:00:00
# Name: DT, dtype: datetime64[ns]

# %%
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2                  DT
# 0     0       300        400 2021-11-18 12:00:00
# 1     1       500        600 2021-11-18 14:00:00
# 2     2       400        500 2021-11-18 16:00:00
# 3     3       200        300 2021-11-18 18:00:00
# 4     4      1000       1100 2021-11-18 20:00:00
# 5     5       120        220 2021-11-18 22:00:00

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.set_title("Nasz pierwszy wykres")

ax.set_xlabel("Czas", rotation=45, labelpad=20)
ax.set_ylabel("Sprzedaż")

plt.xticks(rotation=45, ha='right')

ax.plot(dane['DT'], dane['Sprzedaz'])
ax.plot(dane['DT'], dane['Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
# https://stackoverflow.com/questions/49143513/plot-time-only-in-matplotlib-instead-of-datetime

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots(figsize=(15, 5))

ax.set_title("Nasz pierwszy wykres")



ax.set_xlabel("Czas", rotation=45, labelpad=20)
ax.set_ylabel("Sprzedaż")




plt.grid(True)

plt.xticks(rotation=45, ha='right')


xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'])
ax.plot(dane['DT'], dane['Sprzedaz2'], linewidth=8.0, linestyle ='--', color='g')

ax.legend(['Sprzedaz', 'Sprzedaż2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(15, 5))

ax.set_title("Nasz pierwszy wykres")

ax.set_xlabel("Czas", rotation=45, labelpad=20)
ax.set_ylabel("Sprzedaż")

plt.grid(True)
plt.yticks(np.arange(0,1000,100)) ## można to funkcja ! jaka ?!

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker=">", markersize=20)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker=">", markersize=30)

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(15, 5))

ax.set_title("Nasz pierwszy wykres")

ax.set_xlabel("Czas", rotation=45, labelpad=20)
ax.set_ylabel("Sprzedaż")

plt.grid(True)
plt.yticks(np.arange(0,1000,100)) ## można to funkcja ! jaka ?!

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker="o", markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker="o", markersize=5)

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
dane['ZAPAS'] = [50,100,500,300,200,100]

# %%
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2                  DT  ZAPAS
# 0     0       300        400 2021-11-18 12:00:00     50
# 1     1       500        600 2021-11-18 14:00:00    100
# 2     2       400        500 2021-11-18 16:00:00    500
# 3     3       200        300 2021-11-18 18:00:00    300
# 4     4      1000       1100 2021-11-18 20:00:00    200
# 5     5       120        220 2021-11-18 22:00:00    100

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(15, 5))

ax.set_title("Nasz pierwszy wykres")

ax.set_xlabel("Czas", rotation=45, labelpad=20)
ax.set_ylabel("Sprzedaż")

plt.grid(True)
plt.yticks(np.arange(0,1000,100)) ## można to funkcja ! jaka ?!

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.bar(dane['DT'], dane['ZAPAS'], color ='maroon',  width = 0.05)
     
## -- wykres liniowy
ax.plot(dane['DT'], dane['Sprzedaz'], marker="o", markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker="o", markersize=5)


for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax.annotate(str(j),xy=(i,j/3), color='black', bbox=dict(fc='white', alpha=0.7))

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt


fig, ax2 = plt.subplots(figsize=(15, 10))

ax2.bar(dane['DT'], dane['ZAPAS'], color ='cyan',  width = 0.05)
ax2.set_ylabel('Zapas', color='r')
ax2.set_xlabel("Czas", rotation=45)
     
    
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax2.annotate(str(j),xy=(i,j/3), color='black', va='bottom', bbox=dict(boxstyle='round,pad=0.2', fc='white', alpha=0.7))
    
    
    
ax = ax2.twinx()
ax.set_title("Nasz pierwszy wykres")


ax.set_ylabel("Sprzedaż")

plt.grid(True)
plt.yticks(np.arange(0,1200,100))

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)



ax.plot(dane['DT'], dane['Sprzedaz'], marker="o", markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker="o", markersize=5)

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(str(j),xy=(i,j))

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt


fig, ax = plt.subplots(2,1, figsize=(15, 10))

ax[0].set_title("Nasz pierwszy wykres")

ax[0].set_xlabel("Czas", rotation=45, labelpad=20)
ax[0].set_ylabel("Sprzedaż")

ax[0].grid(True)

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)



ax[0].plot(dane['DT'], dane['Sprzedaz'], marker="o", markersize=5)
ax[0].plot(dane['DT'], dane['Sprzedaz2'], marker="o", markersize=5)

# plt.grid(True)
# plt.yticks(np.arange(0,1200,100)) ## można to funkcja ! jaka ?!


ax[1].bar(dane['DT'], dane['ZAPAS'], color ='maroon',  width = 0.05)
ax[1].grid(True)

plt.gcf().axes[1].xaxis.set_major_formatter(xformatter)

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax[0].annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax[0].annotate(str(j),xy=(i,j))
    
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax[1].annotate(str(j),xy=(i,j/3), color='black', va='bottom', bbox=dict(boxstyle='round,pad=0.2', fc='white', alpha=0.7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22148\3682281157.py in <module>
#      17
#      18
# ---> 19 ax[0].plot(dane['DT'], dane['Sprzedaz'], marker="o", markersize=5)
#      20 ax[0].plot(dane['DT'], dane['Sprzedaz2'], marker="o", markersize=5)
#      21
#
# NameError: name 'dane' is not defined

# %%
import numpy as np
import bokeh
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.plotting import figure, show
bokeh.sampledata.download()
from bokeh.sampledata.stocks import AAPL

dates = np.array(AAPL['date'], dtype=np.datetime64)
source = ColumnDataSource(data=dict(date=dates, close=AAPL['adj_close']))

p = figure(height=300, width=800, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef", x_range=(dates[1500], dates[2500]))

p.line('date', 'close', source=source)
p.yaxis.axis_label = 'Price'

select = figure(title="Drag the middle and edges of the selection box to change the range above",
                height=130, width=800, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None, background_fill_color="#efefef")

range_tool = RangeTool(x_range=p.x_range)
range_tool.overlay.fill_color = "navy"
range_tool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source)
select.ygrid.grid_line_color = None
select.add_tools(range_tool)
select.toolbar.active_multi = range_tool

show(column(p, select))
# Out:
# Using data directory: C:\Users\pawel\.bokeh\data
# Skipping 'CGM.csv' (checksum match)
# Skipping 'US_Counties.zip' (checksum match)
# Skipping 'us_cities.json' (checksum match)
# Skipping 'unemployment09.csv' (checksum match)
# Skipping 'AAPL.csv' (checksum match)
# Skipping 'FB.csv' (checksum match)
# Skipping 'GOOG.csv' (checksum match)
# Skipping 'IBM.csv' (checksum match)
# Skipping 'MSFT.csv' (checksum match)
# Skipping 'WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.zip' (checksum match)
# Skipping 'gapminder_fertility.csv' (checksum match)
# Skipping 'gapminder_population.csv' (checksum match)
# Skipping 'gapminder_life_expectancy.csv' (checksum match)
# Skipping 'gapminder_regions.csv' (checksum match)
# Skipping 'world_cities.zip' (checksum match)
# Skipping 'airports.json' (checksum match)
# Skipping 'movies.db.zip' (checksum match)
# Skipping 'airports.csv' (checksum match)
# Skipping 'routes.csv' (checksum match)
# Skipping 'haarcascade_frontalface_default.xml' (checksum match)

# %%
import pandas as pd

from bokeh.palettes import Spectral4
from bokeh.plotting import figure, show
from bokeh.sampledata.stocks import AAPL, GOOG, IBM, MSFT




p = figure(width=800, height=250, x_axis_type="datetime")
p.title.text = 'Click on legend entries to hide the corresponding lines'

for data, name, color in zip([AAPL, IBM, MSFT, GOOG], ["AAPL", "IBM", "MSFT", "GOOG"], Spectral4):
    df = pd.DataFrame(data)
    df['date'] = pd.to_datetime(df['date'])
    p.line(df['date'], df['close'], line_width=2, color=color, alpha=0.8, legend_label=name)

p.legend.location = "top_left"
p.legend.click_policy="hide"

show(p)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']


ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

    
ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']


ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

for bars in ax.containers:
    ax.bar_label(bars)
    
ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

    
ax.bar(labels, men_means, width, yerr=men_std, label='Men')

ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')


    
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

    
ax.bar(labels, men_means, width, yerr=men_std, label='Men', color='green')

ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women', color='red')


    
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import pandas as pd
df = pd.DataFrame([['A', 10, 12, 2, 20], 
                  ['B', 10, 23, 12, 18],
                  ['C', 12, 15, 19, 6],
                  ['D', 10, 18, 11, 19]],
     columns=['Team', 'C++', 'Java', 'Python', 'Php'])

# %%
df
# Out:
#   Team  C++  Java  Python  Php
# 0    A   10    12       2   20
# 1    B   10    23      12   18
# 2    C   12    15      19    6
# 3    D   10    18      11   19

# %%
df.plot(kind='bar', title='Wykres skumulowany', stacked=True, figsize=(20,12))
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])

# %%
# Define Data


df = pd.DataFrame({
    'Male': [35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

# Plot stacked bar chart


ax = df.plot(stacked=True, kind='bar')

for bar in ax.patches:
    height = bar.get_height() ## bierzemy wysokośc słupka
   
    width = bar.get_width() ## bierzemy szerokość słupka

    x = bar.get_x() ## bierzemy wartość x słupka
    y = bar.get_y() ## bierzemy wartośc y słupka
    label_text = height ## co chcemy wstawić ?
    label_x = x + width / 2 ## 
    label_y = y + height / 2
    ax.text(label_x, label_y, label_text, ha='center',    
            va='center')
    
# Set Tick labels


ax.set_xticklabels(Class,rotation='horizontal')

# Display chart


plt.show()

# %%
ax = df.plot(stacked=True, kind='bar')

# %%
df
# Out:
#    Male  Female
# 0    35      20
# 1    20      11
# 2    43      18
# 3    12       6
# 4    19       9

# %%
# Define Data


df = pd.DataFrame({
    'Male': [-35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

# Plot stacked bar chart


ax = df.plot(stacked=True, kind='barh')

# for bar in ax.patches:
#     height = bar.get_height()
#     width = bar.get_width()
#     x = bar.get_x()
#     y = bar.get_y()
#     label_text = height
#     label_x = x + width / 2
#     label_y = y + height / 2
#     ax.text(label_x, label_y, label_text, ha='center',    
#             va='center')
    
# Set Tick labels


ax.set_xticklabels(Class,rotation='horizontal')

# Display chart


plt.show()
# Out:
# C:\Users\pawel\AppData\Local\Temp\ipykernel_13356\2579098515.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(Class,rotation='horizontal')

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.3, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

# %%
fig1, ax1 = plt.subplots()
ax1.pie(sizes, 
        explode=explode, 
        labels=labels, 
        autopct='%1.1f%%',
        shadow=True, 
        startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.pie(sizes, 
        explode=explode, 
        labels=labels, 
        autopct='%1.1f%%',
        shadow=False, 
        startangle=180,  radius=0.5)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()

labels = ['label1', 'label2', 'label3']
size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

ax.pie(vals.sum(axis=1), labels=labels, radius=1, 
       colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Pie plot with `ax.pie`')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Rectangular box plot')



# # notch shape box plot
# bplot2 = ax2.boxplot(all_data,
#                      notch=True,  # notch shape
#                      vert=True,  # vertical box alignment
#                      patch_artist=True,  # fill with color
#                      labels=labels)  # will be used to label x-ticks



# ax2.set_title('Notched box plot')





# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

        
        
# adding horizontal grid lines
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %%
len(all_data)
# Out:
# 3

# %%
type(all_data)
# Out:
# list

# %%
all_data[2]
# Out:
# array([ 4.83045738,  1.42193285, -6.9345932 , -1.35954345, -2.49500827,
#        -0.7893886 , -0.76012339,  0.31392296, -1.01531248, -3.44408271,
#        -1.58316565, -0.36243196,  0.52285761, -1.91668919, -0.25523529,
#         4.8806895 ,  2.18852461,  1.16210509,  0.40822379,  0.47578034,
#        -0.26209385, -2.19351366,  3.74013443,  2.13702915, -3.51768982,
#         1.31685472, -1.57709442,  1.35644046,  2.48834262,  6.30876723,
#         1.53312052,  6.42308899, -1.83969761,  6.16816411, -0.07337709,
#         5.04863024,  3.32658567,  2.8659232 , -1.32391509, -1.3886835 ,
#         3.27925724, -4.13012927,  0.65451438, -6.57448722,  2.70457111,
#         5.74616587,  2.95656564,  0.57883921, -1.17300856, -2.32890542,
#        -0.95105104,  0.0699205 ,  1.65472028,  4.3863777 ,  4.03976644,
#        -1.12844985, -0.40093067,  3.82721303,  1.16430014, -4.68823423,
#         1.50921907, -4.06488984,  3.69046832, -3.04422812,  0.67381431,
#        -0.46232263, -6.03766062,  4.98654966,  2.84177138, -7.72550512,
#         1.18476239, -0.72860318,  2.22919106,  0.06483183,  5.46396285,
#        -4.9138282 ,  0.28468288, -0.52005416,  1.66550236,  1.26969055,
#        -2.42961648, -3.76321567,  2.34452045, -3.35428831, -2.55074023,
#         0.71204986,  0.62105847,  0.10790211, -0.76853466, -1.74468047,
#         0.09652717, -0.7567912 , -1.29065449,  1.67094676,  1.80915853,
#        -1.25548232,  4.92087204,  2.56928665,  1.51559914,  0.25078777])
