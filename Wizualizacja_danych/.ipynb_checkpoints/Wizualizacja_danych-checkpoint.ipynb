# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# %%
fig, ax=plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])

# %%
dane = pd.DataFrame({'Czas' : [0,1,2,3,4,5],
                     'Sprzedaz' : [300,500,400,200,1000,120] })
dane
# Out:
#    Czas  Sprzedaz
# 0     0       300
# 1     1       500
# 2     2       400
# 3     3       200
# 4     4      1000
# 5     5       120

# %%
fig, ax=plt.subplots()
ax.plot(dane)
# Out:
# [<matplotlib.lines.Line2D at 0x21ad88b6380>,
#  <matplotlib.lines.Line2D at 0x21ad88b63e0>]

# %%
fig, ax=plt.subplots()
ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas")
ax.set_ylabel("Sprzedaż")
ax.plot(dane["Czas"],dane["Sprzedaz"])

# %%
fig, ax=plt.subplots()
ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas")
ax.set_ylabel("Sprzedaż")
ax.plot(dane["Czas"],dane["Sprzedaz"])

for i,j in zip(dane["Czas"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

# %%
fig, ax=plt.subplots(figsize=(10,5))
ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas")
ax.set_ylabel("Sprzedaż")
ax.plot(dane["Czas"],dane["Sprzedaz"])

for i,j in zip(dane["Czas"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

# %%
dane['Sprzedaz2'] = dane['Sprzedaz'] + 100
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2
# 0     0       300        400
# 1     1       500        600
# 2     2       400        500
# 3     3       200        300
# 4     4      1000       1100
# 5     5       120        220

# %%
fig, ax=plt.subplots(figsize=(10,5))  # Tu deklarujemy wykres fig

ax.set_title("Pierwsza wykres")   # Tu konfigurujemy wykres
ax.set_xlabel("Czas")
ax.set_ylabel("Sprzedaż")

ax.plot(dane["Sprzedaz"])    # Tu plotujemy i oznaczamy punkty etykietami z wartościami
for i,j in zip(dane["Czas"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

ax.plot(dane["Sprzedaz2"])
for i,j in zip(dane["Czas"], dane["Sprzedaz2"]):
    ax.annotate(str(j), xy=(i,j))

# %%
from datetime import datetime
datatime_list = [datetime(2021, 11, 18, 12), datetime(2021, 11, 18, 14), datetime(2021, 11, 18, 16),datetime(2021, 11, 18, 18), datetime(2021, 11, 18, 20), datetime(2021, 11, 18, 22)]
dane['DT'] = datatime_list

# %%
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2                  DT
# 0     0       300        400 2021-11-18 12:00:00
# 1     1       500        600 2021-11-18 14:00:00
# 2     2       400        500 2021-11-18 16:00:00
# 3     3       200        300 2021-11-18 18:00:00
# 4     4      1000       1100 2021-11-18 20:00:00
# 5     5       120        220 2021-11-18 22:00:00

# %%
fig, ax=plt.subplots(figsize=(10,5))  # Tu deklarujemy wykres fig

ax.set_title("Pierwsza wykres")   # Tu konfigurujemy wykres
ax.set_xlabel("Czas")
ax.set_ylabel("Sprzedaż")

ax.plot(dane["DT"], dane["Sprzedaz"])    # Tu plotujemy i oznaczamy punkty etykietami z wartościami
for i,j in zip(dane["DT"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

ax.plot(dane["DT"], dane["Sprzedaz2"])
for i,j in zip(dane["DT"], dane["Sprzedaz2"]):
    ax.annotate(j, xy=(i,j))

# %%
fig, ax=plt.subplots(figsize=(10,5))  # Tu deklarujemy wykres fig

ax.set_title("Pierwsza wykres")   # Tu konfigurujemy wykres
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaż")

plt.xticks(rotation=45, ha='right')
ax.plot(dane["DT"], dane["Sprzedaz"])    # Tu plotujemy i oznaczamy punkty etykietami z wartościami
for i,j in zip(dane["DT"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

ax.plot(dane["DT"], dane["Sprzedaz2"])
for i,j in zip(dane["DT"], dane["Sprzedaz2"]):
    ax.annotate(j, xy=(i,j))

# %%
# Tu deklarujemy wykres fig
fig, ax=plt.subplots(figsize=(10,5))  
# Tu konfigurujemy wykres
ax.set_title("Pierwsza wykres")   
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaż")

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

plt.xticks(rotation=45, ha='right')

# Tu plotujemy i oznaczamy punkty etykietami z wartościami
ax.plot(dane["DT"], dane["Sprzedaz"])    
for i,j in zip(dane["DT"], dane["Sprzedaz"]):
    ax.annotate(str(j), xy=(i,j))

ax.plot(dane["DT"], dane["Sprzedaz2"])
for i,j in zip(dane["DT"], dane["Sprzedaz2"]):
    ax.annotate(j, xy=(i,j))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(7,3))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'])
ax.plot(dane['DT'], dane['Sprzedaz2'], linewidth=8.0, linestyle='--', color='g')
ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(7,3))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10)
ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(7,3))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")
plt.grid(True)

plt.xticks(rotation=45, ha='right')

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10)
ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(7,3))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.yticks(np.arange(0,1000,100))

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10 )

ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))

# %%
# Wykresy słupkowe
dane['ZAPAS']=[50,100,500,300,200,100]
dane
# Out:
#    Czas  Sprzedaz  Sprzedaz2                  DT  ZAPAS
# 0     0       300        400 2021-11-18 12:00:00     50
# 1     1       500        600 2021-11-18 14:00:00    100
# 2     2       400        500 2021-11-18 16:00:00    500
# 3     3       200        300 2021-11-18 18:00:00    300
# 4     4      1000       1100 2021-11-18 20:00:00    200
# 5     5       120        220 2021-11-18 22:00:00    100

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(7,3))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.yticks(np.arange(0,1000,100))

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10 )
ax.bar(dane['DT'], dane['ZAPAS'], color='maroon', width=0.05)

ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax.annotate(j, xy=(i,j / 3), color='cyan')

# %%
import matplotlib.dates as mdates
fig, ax = plt.subplots(figsize=(10,5))

ax.set_title("Pierwsza wykres")
ax.set_xlabel("Czas", rotation=45)
ax.set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.yticks(np.arange(0,1000,100))

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)

ax.plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax.plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10 )
ax.bar(dane['DT'], dane['ZAPAS'], color='cyan', width=0.05)

ax.legend(['Sprzedaz', 'Sprzedaz2'])

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax.annotate(str(j), xy=(i,j))
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax.annotate(j, xy=(i,j))
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax.annotate(j, xy=(i,j / 3), color='black', bbox=dict(fc='white', alpha=0.7))

# %%
fig, ax = plt.subplots(2,4, figsize=(20,8))

# %%
fig, ax = plt.subplots(2,1, figsize=(20,8))

ax[0].set_title("Pierwsza wykres")
ax[0].set_xlabel("Czas", rotation=45)
ax[0].set_ylabel("Sprzedaz")

plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.yticks(np.arange(0,1000,100))

xformatter = mdates.DateFormatter('%H:%M')
plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)


ax[0].plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax[0].plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10 )


ax[0].legend(['Sprzedaz', 'Sprzedaz2'])

ax[1].bar(dane['DT'], dane['ZAPAS'],  width=0.05, color='cyan')

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax[0].annotate(str(j), xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax[0].annotate(j, xy=(i,j))
    
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax[1].annotate(j, xy=(i,j/3), color='black', bbox=dict(fc='white', alpha=0.7))

# %%
fig, ax = plt.subplots(2,1, figsize=(20,8))

ax[0].set_title("Pierwsza wykres")
ax[0].set_xlabel("Czas", rotation=45)
ax[0].set_ylabel("Sprzedaz")

# plt.xticks(rotation=45, ha='right')
plt.yticks(np.arange(0,1000,100))

xformatter = mdates.DateFormatter('%H:%M')
# plt.gcf().axes[0].xaxis.set_major_formatter(xformatter)


ax[0].plot(dane['DT'], dane['Sprzedaz'], marker='o', markersize=5)
ax[0].plot(dane['DT'], dane['Sprzedaz2'], marker='o', markersize=10 )
ax[0].grid(True)

ax[0].legend(['Sprzedaz', 'Sprzedaz2'])



for tick in ax[0].get_xticklabels():
    tick.set_rotation(45)
    
for tick in ax[1].get_xticklabels():
    tick.set_rotation(45)
    
    

ax[1].bar(dane['DT'], dane['ZAPAS'],  width=0.05, color='cyan')
ax[1].grid(True)

for i,j in zip(dane['DT'],dane['Sprzedaz']):
    ax[0].annotate(str(j), xy=(i,j))
    
for i,j in zip(dane['DT'],dane['Sprzedaz2']):
    ax[0].annotate(j, xy=(i,j))
    
for i,j in zip(dane['DT'],dane['ZAPAS']):
    ax[1].annotate(j, xy=(i,j/3), color='black', bbox=dict(fc='white', alpha=0.7))

# %%
import bokeh as bk
bk.sampledata.download()
# Out:
# Creating C:\Users\Kacper\.bokeh directory
# Creating C:\Users\Kacper\.bokeh\data directory
# Using data directory: C:\Users\Kacper\.bokeh\data
# Downloading: CGM.csv (1589982 bytes)
#  1589982   [100.00%%]
# Downloading: US_Counties.zip (3171836 bytes)
#  3171836   [100.00%%]
# Unpacking: US_Counties.csv
# Downloading: us_cities.json (713565 bytes)
#  713565    [100.00%%]
# Downloading: unemployment09.csv (253301 bytes)
#  253301    [100.00%%]
# Downloading: AAPL.csv (166698 bytes)
#  166698    [100.00%%]
# Downloading: FB.csv (9706 bytes)
#  9706      [100.00%%]
# Downloading: GOOG.csv (113894 bytes)
#  113894    [100.00%%]
# Downloading: IBM.csv (165625 bytes)
#  165625    [100.00%%]
# Downloading: MSFT.csv (161614 bytes)
#  161614    [100.00%%]
# Downloading: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.zip (4816256 bytes)
#  4816256   [100.00%%]
# Unpacking: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.csv
# Downloading: gapminder_fertility.csv (64346 bytes)
#  64346     [100.00%%]
# Downloading: gapminder_population.csv (94509 bytes)
#  94509     [100.00%%]
# Downloading: gapminder_life_expectancy.csv (73243 bytes)
#  73243     [100.00%%]
# Downloading: gapminder_regions.csv (7781 bytes)
#  7781      [100.00%%]
# Downloading: world_cities.zip (645274 bytes)
#  645274    [100.00%%]
# Unpacking: world_cities.csv
# Downloading: airports.json (6373 bytes)
#  6373      [100.00%%]
# Downloading: movies.db.zip (5053420 bytes)
#  5053420   [100.00%%]
# Unpacking: movies.db
# Downloading: airports.csv (203190 bytes)
#  203190    [100.00%%]
# Downloading: routes.csv (377280 bytes)
#  377280    [100.00%%]
# Downloading: haarcascade_frontalface_default.xml (930127 bytes)
#  930127    [100.00%%]
# Downloading: SampleSuperstore.csv.zip (167457 bytes)
#  167457    [100.00%%]
# Unpacking: SampleSuperstore.csv

# %%
import pandas as pd

from bokeh.palettes import Spectral4
from bokeh.plotting import figure, show
from bokeh.sampledata.stocks import AAPL, GOOG, IBM, MSFT


p = figure(width=800, height=250, x_axis_type="datetime")
p.title.text = 'Click on legend entries to hide the corresponding lines'

for data, name, color in zip([AAPL, IBM, MSFT, GOOG], ["AAPL", "IBM", "MSFT", "GOOG"], Spectral4):
    df = pd.DataFrame(data)
    df['date'] = pd.to_datetime(df['date'])
    p.line(df['date'], df['close'], line_width=2, color=color, alpha=0.8, legend_label=name)

p.legend.location = "top_left"
p.legend.click_policy="hide"

show(p)

# %%
fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:green', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
ax.containers[0][3]

# %%
df = pd.DataFrame([['A', 10, 12, 2, 20], 
                  ['B', 10, 23, 12, 18],
                  ['C', 12, 15, 19, 6],
                  ['D', 10, 18, 11, 19]],
     columns=['Team', 'C++', 'Java', 'Python', 'Php'])
df
# Out:
#   Team  C++  Java  Python  Php
# 0    A   10    12       2   20
# 1    B   10    23      12   18
# 2    C   12    15      19    6
# 3    D   10    18      11   19

# %%
df.plot(kind='bar', title='Wykres skumulowany', stacked=True, figsize=(20,12))
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])

# %%
df = pd.DataFrame({
    'Male': [35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

ax = df.plot(stacked=True, kind='bar')

# %%
df = pd.DataFrame({
    'Male': [35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

ax = df.plot(stacked=True, kind='bar')

for bar in ax.patches:
    print(bar)
    height = bar.get_height()
    width = bar.get_width()
# Out:
# Rectangle(xy=(-0.25, 0), width=0.5, height=35, angle=0)
# Rectangle(xy=(0.75, 0), width=0.5, height=20, angle=0)
# Rectangle(xy=(1.75, 0), width=0.5, height=43, angle=0)
# Rectangle(xy=(2.75, 0), width=0.5, height=12, angle=0)
# Rectangle(xy=(3.75, 0), width=0.5, height=19, angle=0)
# Rectangle(xy=(-0.25, 35), width=0.5, height=20, angle=0)
# Rectangle(xy=(0.75, 20), width=0.5, height=11, angle=0)
# Rectangle(xy=(1.75, 43), width=0.5, height=18, angle=0)
# Rectangle(xy=(2.75, 12), width=0.5, height=6, angle=0)
# Rectangle(xy=(3.75, 19), width=0.5, height=9, angle=0)

# %%
df = pd.DataFrame({
    'Male': [35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

ax = df.plot(stacked=True, kind='bar')

for bar in ax.patches:
    print(bar)
    height = bar.get_height()
    width = bar.get_width()
    
    x = bar.get_x()
    y = bar.get_y()
    
    label_text = height
    label_x = x + width / 2
    label_y = y + height / 2
    ax.text(label_x, label_y, label_text, ha='center', va='center', color='white')

ax.set_xticklabels(Class, rotation='horizontal')
plt.show()
# Out:
# Rectangle(xy=(-0.25, 0), width=0.5, height=35, angle=0)
# Rectangle(xy=(0.75, 0), width=0.5, height=20, angle=0)
# Rectangle(xy=(1.75, 0), width=0.5, height=43, angle=0)
# Rectangle(xy=(2.75, 0), width=0.5, height=12, angle=0)
# Rectangle(xy=(3.75, 0), width=0.5, height=19, angle=0)
# Rectangle(xy=(-0.25, 35), width=0.5, height=20, angle=0)
# Rectangle(xy=(0.75, 20), width=0.5, height=11, angle=0)
# Rectangle(xy=(1.75, 43), width=0.5, height=18, angle=0)
# Rectangle(xy=(2.75, 12), width=0.5, height=6, angle=0)
# Rectangle(xy=(3.75, 19), width=0.5, height=9, angle=0)

# %%
height = bar.get_height()
height
# Out:
# 9.0

# %%
df
# Out:
#    Male  Female
# 0    35      20
# 1    20      11
# 2    43      18
# 3    12       6
# 4    19       9

# %%
df = pd.DataFrame({
    'Male': [35, 20, 43, 12, 19],
    'Female': [20, 11, 18, 6, 9]
 })

Class = ["Fisrt","Second","Third","Fourth","Fifth"]

ax = df.plot(stacked=False, kind='box')

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.3, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots()
ax.pie(sizes)

plt.plot()
# Out:
# []

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.3, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)

plt.plot()
# Out:
# []

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0.5 , 0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots()
ax.pie(sizes,
       labels=labels,
       explode=explode,
      autopct='%1.0f%%',
      radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x214b994f2b0>,
#   <matplotlib.patches.Wedge at 0x214b994f070>,
#   <matplotlib.patches.Wedge at 0x214b994c370>,
#   <matplotlib.patches.Wedge at 0x214b99724d0>],
#  [Text(1.9156640087275576, 0.9760796103115076, 'Frogs'),
#   Text(-0.5098781582571872, 1.569243213696417, 'Hogs'),
#   Text(-0.7944832577533325, -1.5592614768375612, 'Dogs'),
#   Text(1.5692432733692045, -0.5098779746032422, 'Logs')],
#  [Text(1.2474091219621304, 0.6355867229935398, '15%'),
#   Text(-0.2781153590493748, 0.8559508438344091, '30%'),
#   Text(-0.4539904330019042, -0.8910065581928919, '45%'),
#   Text(0.8559508763832023, -0.27811525887449573, '10%')])

# %%
fig, ax = plt.subplots()

labels = ['label1', 'label2', 'label3']
size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap=plt.colormaps['tab20c']
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1,2,5,6,9,10])

ax.pie(vals.sum(axis=1),
       labels=labels,
       radius=1,
       colors=outer_colors,
      wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(),
       radius=1-size,
       colors=inner_colors,
      wedgeprops=dict(width=size, edgecolor='w'))
ax.set(aspect='equal',title='second pie')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
vals
# Out:
# array([[60., 32.],
#        [37., 40.],
#        [29., 10.]])

# %%
vals.flatten()
# Out:
# array([60., 32., 37., 40., 29., 10.])

# %%
outer_colors
# Out:
# array([[0.19215686, 0.50980392, 0.74117647, 1.        ],
#        [0.90196078, 0.33333333, 0.05098039, 1.        ],
#        [0.19215686, 0.63921569, 0.32941176, 1.        ]])

# %%
vals.sum(axis=1)
# Out:
# array([92., 77., 39.])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     notch=False,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Rectangular box plot')



# notch shape box plot
bplot2 = ax2.boxplot(all_data,
                     notch=True,  # notch shape
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks



ax2.set_title('Notched box plot')





# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

        
        
# adding horizontal grid lines
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()
